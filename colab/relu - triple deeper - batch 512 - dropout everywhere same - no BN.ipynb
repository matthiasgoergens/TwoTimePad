# %%
# !rm -rf TwoTimePad
# !git clone --depth 1 https://github.com/matthiasgoergens/TwoTimePad.git
# !rm -rf data *.h5
# !cp -r TwoTimePad/data TwoTimePad/*.h5 ./
# !pip install -q --no-deps tensorflow-addons

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(f'Found device at: {device_name}')
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
device_name = tf.test.gpu_device_name()

if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

with tf.device('/device:GPU:0'):
  import pathlib
  import re

  import tensorflow
  import tensorflow as tf
  from tensorflow import keras


  import pathlib
  import numpy as np
  import random
  from pprint import pprint

  # Train with longer later.
  # n = 25
  # n = 50

  np.set_printoptions(precision=4)


  # Idea:
  # Load corpus, and clean, convert into numbers
  # Repeatedly:
  #   create a batch of data
  #   train
  #   Optional: show current results.

  alpha =    " ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789.?,-:;'()".lower()
  alphaRE = alpha.replace("-","\\-")

  assert len(alpha) == 46

  def load():
    text = ' '.join(f.open('r').read() for f in pathlib.Path('data').glob('*.txt')).lower()
    text = re.sub('\s+', ' ', text)
    text = re.sub(f'[^{alphaRE}]', '', text)
    return text

  def add(clear, key):
    return [(a+b) % len(alpha) for a, b in zip(clear, key)]

  def sub(cipher, key):
    return [(a-b) % len(alpha) for a, b in zip(cipher, key)]

  def clean(text):
    t = {c: i for i, c in enumerate(alpha)}
    return [t[c] for c in text]

  def toChar(numbers):
    return ''.join(alpha[i] for i in numbers)

  # toChar
  # (5, 125, 46)
  def toChars(tensor):
    (linesNums, charNum, alphaNum) = tensor.shape
    output = []
    # TODO: use gather https://www.tensorflow.org/api_docs/python/tf/gather?version=stable
    assert alphaNum == len(alpha)
    for lineNum in range(linesNums):
      chars = []
      for cN in range(charNum):
        (_, char) = max([(tensor[lineNum, cN, alphaN], alphaN) for alphaN in range(alphaNum)])
        chars.append(char)
      output.append(toChar(chars))
    return output

  def toChars_labels(labels):
    (linesNums, charNum) = labels.shape
    output = []
    for lineNum in range(linesNums):
      chars = []
      for cN in range(charNum):
        chars.append(labels[lineNum, cN])
      output.append(toChar(chars))
    return output


  def prepare(clear, key):
    assert len(clear) == len(key), (clear, key)

    # depth = len(alpha)

    # label = clear[len(clear)//2:len(clear)//2+1]
    return sub(clear, key)



  def sample(text, l):
    start = random.randrange(len(text) - l)
    return text[start:start+l]

  # def slicer(n):
  #   mid = round(n/2)
  #   return slice(mid, mid + 1)

  def slicer(n):
    return slice(20, -20)
    return slice(round(n/3), round (2 * n / 3) + 1)

  def samples(text, batch_size, l):
    ciphersA = []
    ciphersB = []
    keys = []
    labelsA = []
    labelsB = []
    for _ in range(batch_size):
      clearA = sample(text, l)
      clearB = sample(text, l)

      cipherA = prepare(clearA, clearB)

      ciphersA.append(cipherA)
      labelsA.append(clearA[slicer(l)])
      labelsB.append(clearB[slicer(l)])

    one_hot_ciphersA = tf.convert_to_tensor(ciphersA)

    return ([one_hot_ciphersA], [tf.convert_to_tensor(labelsA)])

  # relu = lambda: keras.activations.relu # (alpha=0.1)
  relu = lambda: keras.layers.LeakyReLU(alpha=0.1)
  # keras.layers.Embedding

  from tensorflow.keras.layers import Layer, Concatenate, Embedding, Input, Dense, Dropout, Softmax, GlobalMaxPooling1D, MaxPooling1D, Conv1D, Flatten, concatenate, Bidirectional, LSTM, SimpleRNN, Add
  from tensorflow_addons.optimizers import CyclicalLearningRate
  from tensorflow.keras.models import Sequential, Model
  import tensorflow_addons as tfa

  Maxout = tfa.layers.Maxout
  def make_model(n):
    inputA = Input(shape=(n,), dtype='int32', name="cipherA")

    emb = Embedding(output_dim=len(alpha), input_dim=len(alpha), name="my_embedding")
    embedded = emb(inputA)

    # relud = lambda base: relu()(Dense()(base))
    # Idea is to bubble up better and better guesses for what letters we have locally.
    
    # I don't think the dropout here is a great idea?
    # Perhaps have the same dropout for each layer instead?

    dropout = tf.keras.layers.SpatialDropout1D(0.5)
    conv1 = lambda base: (Conv1D(
        filters=46*2*2 * 5, kernel_size=5,
        padding='same', strides=1)(
          base
        ))

    pseudo_maxout = lambda l: tfa.layers.Maxout(46*2*2)(l)
    pseudo_maxout = lambda l: relu()(Conv1D(
        filters=46*2*2, kernel_size=1,
        padding='same', strides=1)(relu()(l)))

    conv = lambda base: dropout(Add()([base, conv1(pseudo_maxout(base))]))
    # Not sure whether the eta abstraction is necessary?
    lstm_ed = (
      (conv(
      (conv(
      (conv(
      (conv(
      (conv(
      (conv(
      (conv(
      (conv(
      conv1(embedded)
    )))))))))))))))))

    totes_clear = (
      (Conv1D(
        filters=len(alpha), kernel_size=5,
        padding='same', strides=1)(
      (lstm_ed)
    )))[:, slicer(n), :]
    model = Model([inputA], [Layer(name="clear")(totes_clear)])

    model.compile(
      optimizer=tf.keras.optimizers.Adam(),
      loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
      metrics=['accuracy'])
    return model

  import sys

  # TODO: implement generator or read from file?
  # Or use dataset and augment?
  training_size = 2 * (2**10) ** 2
  test_size = 10**3
  batch_size = 512

update_freq = 200

from datetime import datetime
name = '2021-June'
logdir = f"/content/drive/My Drive/twotimepad/logs/fit2/{datetime.now().strftime('%Y%m%d-%H%M%S')}_{name}"
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir, profile_batch=0, update_freq='batch')
# update_freq -> set to more often.

from keras.callbacks import *
weights_name = f'/content/drive/My Drive/twotimepad/{name}-checkpoint.tf'
# checkpoint = ModelCheckpoint(weights_name, monitor='loss', verbose=1, save_best_only=True, save_freq=update_freq)
checkpoint = ModelCheckpoint(weights_name, verbose=1, save_freq=update_freq)

from tensorflow.keras.callbacks.experimental import BackupAndRestore
# from pathlib import Path
# Path(f'/content/drive/My Drive/twotimepad/{name}/foo').touch()
backup = BackupAndRestore(f'/content/drive/My Drive/twotimepad/{name}-backup_restore/')

callbacks_list = [checkpoint, tensorboard_callback, backup]

# %%
with tf.device('/device:GPU:0'):
  from google.colab import drive
  drive.mount('/content/drive')

  import sys
# Out:
# Mounted at /content/drive

# %%
start_l = 100
max_l = 100

# %%
import itertools as it
first = True

# epochs_batch = 10
l = start_l
model = make_model(l)
model.summary()
text = clean(load())
try:
  model.load_weights(weights_name)
  print("Loaded weights.")
except Exception as e:
  print(f"Got: {e}")
  print("Failed to load weights.  Starting from scratch.")

with tf.device('/device:GPU:0'):
  for epoch in it.count():
    # l = min(max_l, l)

    print("Predict:")
    predict_size = 5
    print(f"samples(text, predict_size, l): {predict_size}, {l})")
    (inputs_p, labels_p) = samples(text, predict_size, l)
    [ciphersA_p] = labels_p
    predictA_p = model.predict(inputs_p)
    pprint(list(zip(

        toChars_labels(ciphersA_p),
        toChars(predictA_p),

        )),
      width=l+10)
    print("Training:")
    (inputs, [labels]) = samples(text, training_size, l)

    model.fit(x=inputs, y=labels,
              batch_size=batch_size,
              # validation_data=(ciphers_t, [labels_t, keys_t]),
              callbacks=callbacks_list,
              # epochs=epochs_batch * (epoch+1), initial_epoch=epochs_batch  * epoch
              validation_split=0.01,
              epochs=100,
              )
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# cipherA (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# my_embedding (Embedding)        (None, 100, 46)      2116        cipherA[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 100, 920)     212520      my_embedding[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 100, 920)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 100, 184)     169464      leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 100, 184)     0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 100, 920)     847320      leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 100, 920)     0           conv1d[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo (None, 100, 920)     0           add[0][0]
#                                                                  add_1[0][0]
#                                                                  add_2[0][0]
#                                                                  add_3[0][0]
#                                                                  add_4[0][0]
#                                                                  add_5[0][0]
#                                                                  add_6[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 100, 920)     0           spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 100, 184)     169464      leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 100, 184)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 100, 920)     847320      leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 920)     0           spatial_dropout1d[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 100, 920)     0           spatial_dropout1d[1][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 100, 184)     169464      leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 100, 184)     0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 100, 920)     847320      leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 920)     0           spatial_dropout1d[1][0]
#                                                                  conv1d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 100, 920)     0           spatial_dropout1d[2][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 100, 184)     169464      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 100, 184)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 100, 920)     847320      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 100, 920)     0           spatial_dropout1d[2][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 100, 920)     0           spatial_dropout1d[3][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 100, 184)     169464      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 100, 184)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 100, 920)     847320      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 100, 920)     0           spatial_dropout1d[3][0]
#                                                                  conv1d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 100, 920)     0           spatial_dropout1d[4][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 100, 184)     169464      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 100, 184)     0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 100, 920)     847320      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 100, 920)     0           spatial_dropout1d[4][0]
#                                                                  conv1d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 100, 920)     0           spatial_dropout1d[5][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 100, 184)     169464      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 100, 184)     0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 100, 920)     847320      leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 100, 920)     0           spatial_dropout1d[5][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 100, 920)     0           spatial_dropout1d[6][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 100, 184)     169464      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 100, 184)     0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 100, 920)     847320      leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 100, 920)     0           spatial_dropout1d[6][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 100, 46)      211646      spatial_dropout1d[7][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 60, 46)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# clear (Layer)                   (None, 60, 46)       0           tf.__operators__.getitem[0][0]
# ==================================================================================================
# Total params: 8,560,554
# Trainable params: 8,560,554
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Got: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# Failed to load weights.  Starting from scratch.
# Predict:
# samples(text, predict_size, l): 5, 100)
# [('going up to her husband, who was still on his knees, sobbing',
#   ')al?zlma8sfiul 8o?e mmj8s8 )do1cx msjo?8o jb4 o)sy.ec-habh 2'),
#  ('ould be more germane to the matter if we could carry cannon ',
#   '2ymlh.jwcl8 zu2)hlwf scl llct) 4f jz?sce 8wccu z ljv0 hl)884'),
#  ('141, 144, 185. cf. athenum, 15th and 19th of july, 1893. 22 ',
#   'bz0jjsjo?h7.lo z zesdt yajo8o2hcbsm mog yclwl)ecj  m  ?c y8o'),
#  ("r heart's pulsation i assure you, monsieur, they are terrify",
#   'j0x yc2.ocbc;h ziylj8e4o cclc8y?lw:e7lmlcwf)zcjo8p0 u48lzuo?'),
#  ('which to reiterate were sin as deep as that, though true. le',
#   'o.8zuvfej- cwloomsm)scmc8xu0jwjebod?8s4;i9?b)l8y?siwlcu8se2e')]
# Training:
# Epoch 1/100
#  200/4056 [>.............................] - ETA: 31:30 - loss: 2.8903 - accuracy: 0.2124
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
#  400/4056 [=>............................] - ETA: 30:29 - loss: 2.6446 - accuracy: 0.2738
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
#  600/4056 [===>..........................] - ETA: 29:01 - loss: 2.5021 - accuracy: 0.3101
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
#  800/4056 [====>.........................] - ETA: 27:25 - loss: 2.4046 - accuracy: 0.3351
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 1000/4056 [======>.......................] - ETA: 25:49 - loss: 2.3317 - accuracy: 0.3539
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 1200/4056 [=======>......................] - ETA: 24:10 - loss: 2.2741 - accuracy: 0.3687
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 1400/4056 [=========>....................] - ETA: 22:31 - loss: 2.2268 - accuracy: 0.3809
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 1600/4056 [==========>...................] - ETA: 20:50 - loss: 2.1869 - accuracy: 0.3913
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 1800/4056 [============>.................] - ETA: 19:08 - loss: 2.1526 - accuracy: 0.4001
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 2000/4056 [=============>................] - ETA: 17:27 - loss: 2.1226 - accuracy: 0.4079
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 2200/4056 [===============>..............] - ETA: 15:45 - loss: 2.0961 - accuracy: 0.4147
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 2400/4056 [================>.............] - ETA: 14:03 - loss: 2.0723 - accuracy: 0.4209
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 2600/4056 [==================>...........] - ETA: 12:22 - loss: 2.0508 - accuracy: 0.4265
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 2800/4056 [===================>..........] - ETA: 10:40 - loss: 2.0313 - accuracy: 0.4315
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 3000/4056 [=====================>........] - ETA: 8:58 - loss: 2.0134 - accuracy: 0.4361
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 3200/4056 [======================>.......] - ETA: 7:16 - loss: 1.9969 - accuracy: 0.4404
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 3400/4056 [========================>.....] - ETA: 5:34 - loss: 1.9817 - accuracy: 0.4444
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 3600/4056 [=========================>....] - ETA: 3:52 - loss: 1.9675 - accuracy: 0.4480
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 3800/4056 [===========================>..] - ETA: 2:10 - loss: 1.9543 - accuracy: 0.4515
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 4000/4056 [============================>.] - ETA: 28s - loss: 1.9419 - accuracy: 0.4547
# Epoch 00001: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets
# 4056/4056 [==============================] - 2081s 513ms/step - loss: 1.9385 - accuracy: 0.4556 - val_loss: 1.3925 - val_accuracy: 0.5879
# Epoch 2/100
#  144/4056 [>.............................] - ETA: 31:55 - loss: 1.5446 - accuracy: 0.5593
# Epoch 00002: saving model to /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf
# INFO:tensorflow:Assets written to: /content/drive/My Drive/twotimepad/2021-triple-deeper-no_maxout-callbacks-5-dropout_everywhere_same-no_BN-checkpoint.tf/assets